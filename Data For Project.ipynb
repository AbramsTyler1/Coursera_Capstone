# %% [markdown]
# # Data

# %% [markdown]
# In order to solve the business problem, I will leverage Foursquare location data, k-means clustering, and other data analysis methods.
# For finding nearby cities or towns, I would first convert my friend’s residence address (data) to geographical coordinates (data). Then I will use one of the following websites to study/scrape information regarding nearby cities or towns (data)
# • http://www.city-data.com/city/Germantown-Maryland.html
# • https://www.distancesto.com/city/germantown/us/19404.html
# • https://www.distantias.com/towns-radius-germantown-maryland-united_states.htm • https://www.google.com/maps/place/Germantown,+MD/@39.1760744,-77.3314752
# I will then use Foursquare Venues Search API to find dental facilities (data) in the selected nearby cities/towns (data). For example, following cities are located near Germantown – Gaithersburg & Clarksburg. I will further use the Foursquare Venues Search or Venues Explore APIs to find a public destination (data) in the selected city/town (data). For example, nearby grocery store, movie theater, coffee shop, etc. I will also be visualizing the dental facilities (data) and public destinations (data) on a map, and apply k-means clustering.
